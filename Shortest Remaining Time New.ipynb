# %%
import random

# %%
array=[[],[],[],[],[]]

for i in range(0,5):
    for a in range(random.randint(4,10)):
        b=random.randint(1,8)
        array[i].append(b)
        #print(b)
print("Five Random Arrays of length between 4 to 10 : \n" ,array)
# Out:
# Five Random Arrays of length between 4 to 10 :
#  [[1, 1, 8, 5, 5, 4, 3, 8, 7, 3], [3, 3, 2, 4, 3, 7, 4, 5], [5, 8, 2, 3, 1], [4, 7, 8, 8, 4, 1, 4, 3, 7], [6, 2, 4, 4, 4]]

# %%
arr1=[]
arr1=array[0]
arr2=[]
arr2=array[1]
arr3=[]
arr3=array[2]
arr4=[]
arr4=array[3]
arr5=[]
arr5=array[4]

# %%
print(arr1,arr2,arr3,arr4,arr5)
# Out:
# [1, 1, 8, 5, 5, 4, 3, 8, 7, 3] [3, 3, 2, 4, 3, 7, 4, 5] [5, 8, 2, 3, 1] [4, 7, 8, 8, 4, 1, 4, 3, 7] [6, 2, 4, 4, 4]

# %%
print("process 1: ",arr1)
print("Deleted item: ", arr1[0])
del arr1[0]
print("process 1: ",arr1,'\n',"Process 2: ",arr2)
if len(arr1)>len(arr2):
    print("Deleted item: ", arr2[0])
    del arr2[0]
    
elif len(arr1)<len(arr2):
    print("Deleted item: ", arr1[0])
    del arr1[0]
else:
    print("Deleted item: ", arr1[0])
    del arr1[0]
    
print('Process 1: ',arr1,"\nProcess 2: ",arr2,"\nProcess 3: ",arr3)

if len(arr1)<=len(arr2) and len(arr3):
    print("Deleted item: ", arr1[0])
    del arr1[0]
    
elif len(arr2)<= len(arr1) and len(arr3):
    print("Deleted item: ", arr2[0])
    del arr2[0]

elif len(arr3)<= len(arr1) and len(arr2):
    print("Deleted item: ", arr3[0])
    del arr3[0]
    
print('process 1: ',arr1,"\nProcess 2: ",arr2,"\nProcess 3: ",arr3,"\nProcess 4: ",arr4)

if len(arr1)<=len(arr2) and len(arr3) and len(arr4):
    print("Deleted item: ", arr1[0])
    del arr1[0]
    
elif len(arr2)<= len(arr1) and len(arr3) and len(arr4):
    print("Deleted item: ", arr2[0])
    del arr2[0]
    
elif len(arr3)<= len(arr1) and len(arr2) and len(arr4):
    print("Deleted item: ", arr3[0])
    del arr3[0]
    
elif len(arr4)<= len(arr1) and len(arr2) and len(arr3) :
    print("Deleted item: ", arr4[0])
    del arr4[0]
    
print("Process 1: ",arr1,"\nProcess 2: ",arr2,"\nProcess 3: ",arr3,"\nProcess 4: ",arr4,"\nProcess 5: ",arr5)






while len(arr1)>0 or len(arr2)>0 or len(arr3)>0 or  len(arr4)>0 or  len(arr5)>0:
    
    a=[len(arr1),len(arr2),len(arr3),len(arr4),len(arr5)]
    m= min(i for i in a if i>0)

    if len(arr1)>0 and m== len(arr1):
        print("Deleted item: ", arr1[0])
        del arr1[0]
        
    elif len(arr2)>0 and m==len(arr2):
        print("Deleted item: ", arr2[0])
        del arr2[0]
        
    elif len(arr3)>0 and m==len(arr3):
        print("Deleted item: ", arr3[0])
        del arr3[0]
        
    elif len(arr4)>0 and m==len(arr4):
        print("Deleted item: ", arr4[0])
        del arr4[0]
        
    elif len(arr5)>0 and m==len(arr5):
        print("Deleted item: ", arr5[0])
        del arr5[0]
     
    
    print("Process 1: ",arr1,"\nProcess 2: ",arr2,"\nProcess 3: ",arr3,"\nProcess 4: ",arr4,"\nProcess 5: ",arr5)
    
print("All processes completed")
# Out:
# process 1:  [1, 1, 8, 5, 5, 4, 3, 8, 7, 3]
# Deleted item:  1
# process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
#  Process 2:  [3, 3, 2, 4, 3, 7, 4, 5]
# Deleted item:  3
# Process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
# Process 2:  [3, 2, 4, 3, 7, 4, 5]
# Process 3:  [5, 8, 2, 3, 1]
# Deleted item:  3
# process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
# Process 2:  [2, 4, 3, 7, 4, 5]
# Process 3:  [5, 8, 2, 3, 1]
# Process 4:  [4, 7, 8, 8, 4, 1, 4, 3, 7]
# Deleted item:  2
# Process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
# Process 2:  [4, 3, 7, 4, 5]
# Process 3:  [5, 8, 2, 3, 1]
# Process 4:  [4, 7, 8, 8, 4, 1, 4, 3, 7]
# Process 5:  [6, 2, 4, 4, 4]
# Deleted item:  4
# Process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
# Process 2:  [3, 7, 4, 5]
# Process 3:  [5, 8, 2, 3, 1]
# Process 4:  [4, 7, 8, 8, 4, 1, 4, 3, 7]
# Process 5:  [6, 2, 4, 4, 4]
# Deleted item:  3
# Process 1:  [1, 8, 5, 5, 4, 3, 8, 7, 3]
# Process 2:  [7, 4, 5]
# Process 3:  [5, 8, 2, 3, 1]
# Process 4:  [4, 7, 8, 8, 4, 1, 4, 3, 7]
# ...
